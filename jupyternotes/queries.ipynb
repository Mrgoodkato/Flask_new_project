# %%
key_words = ["a","about","above","after","again","against","all","am","an","and","any","are","aren't","as","at","be","because","been","before","being","below","between","both","but","by","can't","cannot","could","couldn't","did","didn't","do","does","doesn't","doing","don't","down","during","each","few","for","from","further","had","hadn't","has","hasn't","have","haven't","having","he","he'd","he'll","he's","her","here","here's","hers","herself","him","himself","his","how","how's","i","i'd","i'll","i'm","i've","if","in","into","is","isn't","it","it's","its","itself","let's","me","more","most","mustn't","my","myself","no","nor","not","of","off","on","once","only","or","other","ought","our","ours","ourselves","out","over","own","same","shan't","she","she'd","she'll","she's","should","shouldn't","so","some","such","than","that","that's","the","their","theirs","them","themselves","then","there","there's","these","they","they'd","they'll","they're","they've","this","those","through","to","too","under","until","up","very","was","wasn't","we","we'd","we'll","we're","we've","were","weren't","what","what's","when","when's","where","where's","which","while","who","who's","whom","why","why's","with","won't","would","wouldn't","you","you'd","you'll","you're","you've","your","yours","yourself","yourselves"]

punctuation_pattern = r'[!\"#$%&\'()*+,-./:;<=>?@\[\]\^_`{|}~—]'

# %%
import json
import os
import re

#REPEATED FROM chapterOrganizer file (remember to consolidate this method)
def checkKeyWords(string: str):
    """Checks against the keywords list for any matches in the string input

    Args:
        string (str): String that will be checked

    Returns:
        bool: True if the string does not coincide with the list, False if there is a match
    """

    for keyword in key_words:
        match = re.search(rf'^{keyword}$', string=string)
        if(match):
            return False
    
    return True

# %%
def queryStringProcessing(string: str):
    """Function to process and normalize the query string in order to get an array of strings using the checkKeyWords method to remove all banned keywords from the query and punctuation signs

    Args:
        string (str): Query string input

    Returns:
        list: List of strings in the original input after processing with no punctuation or banned keywords
    """

    list_string = string.split(' ')
    result_string = []

    for st in list_string:

        normal_string = re.sub(punctuation_pattern, '', st.lower())
        if(checkKeyWords(normal_string)):
            
            result_string.append(normal_string) 

    
    return result_string



queryStringProcessing('Hola, soy Ricardo, then, for')
# Out:
# ['hola', 'soy', 'ricardo']

# %%
def mapStringQuery(query: list):
    """Function that takes the list query preprocessed in the queryStringProcessing() and processes the list against the string_dict file elements to gather the information for the queryMap object.

    Args:
        query (list): Processed string query input as a list with the banned words removed

    Returns:
        dict: queryMap dictionary comprised of a map with all relevant sections that coincided with a result and an array of objects with the necessary info for each result - section - string.
    """
    queryMap = {
        'map': [],
        'query': []
    }

    with open('test_string_dict/string_dict.json', 'r') as data:
        string_dict = json.load(data)

        for string in query:

            if string in string_dict:
                queryMap['map'].extend(string_dict[string])
                queryMap['query'].append(
                    {
                        'keyword': string,
                        'sections': string_dict[string]
                    }
                )

    #REMOVES THE DUPLICATES IN THE LIST
    queryMap['map'] = list(dict.fromkeys(queryMap['map']))

    return queryMap

def mapHierarchy(queryMap: dict):
    """Function that processes the queryMap object to generate a new object with the coincidences and sections relevant for the final display of the query

    Args:
        queryMap (dict): queryMap dictionary containing the initial result of the query

    Returns:
        dict: Dictionary object with keys as section numbers and value of a coincidence and keyword keys that represent the keywords present in each section with the respective number of coincidences present
    """
    mapCoincidences = {}

    for query in queryMap['query']:
        
        for section in queryMap['map']:

            if(section in query['sections']):

                if(section in mapCoincidences.keys()):
                    mapCoincidences[section]['keyword'].append(query['keyword'])
                    mapCoincidences[section]['coincidence'] =  mapCoincidences[section]['coincidence'] + 1
                else:
                    mapCoincidences[section] = {
                        'coincidence': 1,
                        'keyword': [query['keyword']]
                    }
    
    #Sorted keys to sort all keys in the mapCoincidences dictionary under the coincidence key for each section
    sorted_keys = sorted(mapCoincidences, key=lambda x: mapCoincidences[x]['coincidence'], reverse=True)

    #Create new dictionary to return with the sorted data
    finalCoincidences = {key: mapCoincidences[key] for key in sorted_keys}
    
    return finalCoincidences

# %%
def processCoincidences(coincidences: dict):

    final_result = []

    for key in coincidences:
        with open(f'test_files/{key}.json') as file:

            json_file = json.load(file)

            final_result.append(traverseFile(json_file, coincidences[key]['keyword']))

    return final_result
    


def traverseFile(file, list_string):

    result = []

    for item in file:

        string_coincidences = []
        
        for string in list_string:
            
            match_string = re.search(string, item['description'])

            if(match_string):
                string_coincidences.append(string)
                print(string_coincidences)
            

        result.append(
                {
                    'keyword': string_coincidences,
                    'data': item
                }
            )            

    return result

# %%
query_string = queryStringProcessing('Subsea cat')

print(query_string)

queryMap = mapStringQuery(query_string)

coincidence = mapHierarchy(queryMap)

coincidence
# Out:
# ['subsea', 'cat']
# {'9902': {'coincidence': 2, 'keyword': ['subsea', 'cat']},
#  '2309': {'coincidence': 1, 'keyword': ['cat']}}

# %%
final_result = processCoincidences(coincidence)

final_result
# Out:
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['subsea']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['subsea']
# ['cat']
# ['cat']
# ['subsea']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# ['cat']
# [[{'keyword': [],
#    'data': {'htsno': '9902.01.01',
#     'indent': 0,
#     'description': 'Frozen, boiled glutinous corn (other than sweet corn), not reduced in size (provided for in subheading 0710.80.70)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.02',
#     'indent': 0,
#     'description': 'Mustard seed oil and its fractions, other than crude, not denatured, not chemically modified (provided for in subheading 1514.99.90).',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.03',
#     'indent': 0,
#     'description': 'Cocoa powder, not containing added sugar or other sweetening matter (provided for in subheading 1805.00.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.04',
#     'indent': 0,
#     'description': 'Artichokes, prepared or preserved by vinegar or acetic acid (provided for in subheading 2001.90.25)',
#     'superior': None,
#     'units': [],
#     'general': '7.2%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.05',
#     'indent': 0,
#     'description': 'Pepperoncini, prepared or preserved by vinegar or acetic acid and presented in glass jars (provided for in subheading 2001.90.38)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.06',
#     'indent': 0,
#     'description': 'Pepperoncini, prepared or preserved by vinegar or acetic acid and presented in containers other than glass jars (provided for in subheading 2001.90.38)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.07',
#     'indent': 0,
#     'description': 'Olives, green in color, stuffed with minced pimiento, the foregoing in brine and presented in glass containers, other than place packed (provided for in subheading 2005.70.25) \n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.08',
#     'indent': 0,
#     'description': 'Pimientos, prepared or preserved otherwise than by vinegar or acetic acid, not frozen (provided for in subheading 2005.99.50)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.09',
#     'indent': 0,
#     'description': 'Pepperoncini, prepared or preserved otherwise than by vinegar or acetic acid, not frozen (provided for in subheading 2005.99.55)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.10',
#     'indent': 0,
#     'description': 'Artichokes, prepared or preserved otherwise than by vinegar or acetic acid, not frozen (provided for in subheading 2005.99.80)\n',
#     'superior': None,
#     'units': [],
#     'general': '12.7%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.11',
#     'indent': 0,
#     'description': 'Strawberries, brined and then oven-dried or tunnel-dried, the foregoing infused with sugar (provided for in subheading 2008.80.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.12',
#     'indent': 0,
#     'description': 'Edible powder containing conjugated linoleic acid (CAS Nos. 2540-56-9 and 2420-56-6) containing over 10 percent by weight of milk solids (provided for in subheading 2106.90.82)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.13',
#     'indent': 0,
#     'description': 'Gum containing nicotine and containing synthetic sweetening agents (e.g., saccharin) instead of sugar (provided for in subheading 2106.90.98)\n',
#     'superior': None,
#     'units': [],
#     'general': '5.8%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.14',
#     'indent': 0,
#     'description': 'Coconut water juice blends, not from concentrate, packaged for retail sale (provided for in subheading 2009.90.40).',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.15',
#     'indent': 0,
#     'description': 'Coconut water, not from concentrate, not containing added sugar or other sweetening matter, packaged for retail sale in paper-based cartons (provided for in subheading 2009.89.70)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': ' See chapter 99 statistical note 1. ',
#       'type': 'footnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': ' ',
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.16',
#     'indent': 0,
#     'description': 'Coconut water not from concentrate, flavored, packaged for retail sale (provided for in subheading 2009.89.70)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': ' See chapter 99 statistical note 1. ',
#       'type': 'footnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': ' ',
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.17',
#     'indent': 0,
#     'description': 'Coconut water, not from concentrate, not containing added sugar or other sweetening, certified by the importer as from conventionally grown (non-organic) coconuts, packaged for retail sale in 500 milliliter polyethylene terephthalate bottles (provided for in subheading 2009.89.70)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': ' See chapter 99 statistical note 1. ',
#       'type': 'footnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': ' ',
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.18',
#     'indent': 0,
#     'description': 'Light oil fractions containing more than 50 percent by weight of isododecane (CAS No. 93685-81-5) (provided for in subheading 2710.12.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.19',
#     'indent': 0,
#     'description': 'Medium oil fractions containing more than 50 percent by weight of isohexadecane (CAS No. 93685-80-4) (provided for in subheading 2710.19.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.20',
#     'indent': 0,
#     'description': 'Sodium, containing more than 200 ppm of calcium (CAS No. 7440-23-5) (provided for in subheading 2805.11.00)\n',
#     'superior': None,
#     'units': [],
#     'general': '2.5%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.21',
#     'indent': 0,
#     'description': 'Sodium, containing not more than 200 ppm of calcium (CAS No. 7440-23-5) (provided for in subheading 2805.11.00) \n',
#     'superior': None,
#     'units': [],
#     'general': '0.7%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.22',
#     'indent': 0,
#     'description': 'Nitrosylsulfuric acid (CAS. No. 7782-78-7) (provided for in subheading 2811.19.61)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.23',
#     'indent': 0,
#     'description': 'Hypophosphorous acid 50% (phosphinic acid) (CAS No. 6303-21-5) (provided for in subheading 2811.19.61)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.24',
#     'indent': 0,
#     'description': 'Sulfamic acid (CAS No. 5329-14-6) (provided for in subheading 2811.19.61)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.25',
#     'indent': 0,
#     'description': 'Dihydrogen hexafluorozirconate(2-) (Hexafluorozirconic acid) (CAS No. 12021-95-3) (provided for in subheading 2811.19.61)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.26',
#     'indent': 0,
#     'description': 'Dioxosilane (Silicon dioxide amorphous) (CAS No. 7631-86-9) entirely spherical micro-spheres of mean particle size of 0.005 mm or smaller, uniform particle size with a uniformity coefficient of 1.65 or less, trace metal impurities less than 70 ppm, specific electrical resistance of 50,000 Ohm cm (provided for in subheading 2811.22.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.27',
#     'indent': 0,
#     'description': 'Dioxosilane (Silicon dioxide amorphous) (CAS No. 7631-86-9) entirely spherical micro-spheres of mean particle size of between 0.007 and 0.020 mm, uniform particle size with a uniformity coefficient of 1.65 or less, trace metal impurities less than 70 ppm, specific electrical resistance of 50,000 Ohm cm (provided for in subheading 2811.22.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.28',
#     'indent': 0,
#     'description': 'Dioxosilane (Silicon dioxide amorphous) (CAS No. 7631-86-9) presented in the form of entirely spherical micro-spheres, certified by the importer as having a mean particle size of between 0.046 and 0.054 mm, uniform particle size with a uniformity coefficient of 1.65 or less and specific electrical resistance of 50,000 Ohm cm or more (provided for in subheading 2811.22.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.29',
#     'indent': 0,
#     'description': 'Silicon dioxide amorphous, certified by the importer as comprising entirely spherical micro-spheres with mean particle size of 28 to 45 micrometers (µm) and surface area 600 to 800 m²/g (CAS No. 7631-86-9) (provided for in subheading 2811.22.10)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.30',
#     'indent': 0,
#     'description': 'Amorphous silicon dioxide micro-spheres of mean particle size of 0.050-0.100 mm, and specific electrical resistance of 50,000 Ohm cm or more (CAS No. 7631-86-9) (provided for in subheading 2811.22.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.31',
#     'indent': 0,
#     'description': 'Amorphous silicon dioxide micro-spheres of mean particle size 0.003-0.018 mm, linseed oil absorption 30-40 ml/g, surface area less than 80 m²/g, and pore volume less than 0.1 ml/g (CAS No. 7631-86-9) (provided for in subheading 2811.22.10)\n\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.32',
#     'indent': 0,
#     'description': 'Entirely spherical silicon dioxide micro-spheres, certified by the importer as having mean particle size of 3 to 18 micrometers (µm), linseed oil absorption 150 to 400 ml/g, microbial count less than 100 cfu/g, mold count less than 100 cfu/g, heavy metals less than 20 ppm, surface area 300 to 800 m²/g and pore volume of 0.8 to 2.5 ml/g (CAS No. 7631-86-9) (provided for in subheading 2811.22.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.33',
#     'indent': 0,
#     'description': 'Thionyl chloride (CAS No. 7719-09-7) (provided for in subheading 2812.17.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.34',
#     'indent': 0,
#     'description': 'Chromium(III) oxide (CAS No. 1308-38-9) (provided for in subheading 2819.90.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.35',
#     'indent': 0,
#     'description': 'Iron(III) oxide (Pigment red 101) (CAS No. 1309-37-1) (provided for in subheading 2821.10.00)\n',
#     'superior': None,
#     'units': [],
#     'general': '2.1%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.36',
#     'indent': 0,
#     'description': 'Hydroxylamine (CAS No. 7803-49-8) (provided for in subheading 2825.10.00)',
#     'superior': None,
#     'units': [],
#     'general': '2.7%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.37',
#     'indent': 0,
#     'description': 'Hydroxylamine sulfate (bis(hydroxylammonium) sulfate) (CAS No. 10039-54-0) (provided for in subheading 2825.10.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.38',
#     'indent': 0,
#     'description': 'Hydrazine, 64 percent solution in water (CAS No. 302-01-2) (provided for in subheading 2825.10.00)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.39',
#     'indent': 0,
#     'description': 'Germanium dioxide, powder form (CAS No. 1310-53-8) (provided for in subheading 2825.60.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.40',
#     'indent': 0,
#     'description': 'Tin(IV) oxide (stannic oxide) (Dioxostannane) (CAS No. 18282-10-5) (provided for in subheading 2825.90.20)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.41',
#     'indent': 0,
#     'description': 'Ammonium bifluoride (Ammonium fluoride hydrofluoride (1:1:1)) (CAS No. 1341-49-7) (provided for in subheading 2826.19.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.42',
#     'indent': 0,
#     'description': 'Sodium Fluoride (CAS No. 7681-49-4) (provided for in subheading 2826.19.20)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.43',
#     'indent': 0,
#     'description': 'Tin fluoride (CAS No. 7783-47-3) (provided for in subheading 2826.19.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.44',
#     'indent': 0,
#     'description': 'Sodium hydrogen difluoride (CAS No. 1333-83-1) (provided for in subheading 2826.19.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.45',
#     'indent': 0,
#     'description': 'Chromium(3+) trifluoride (CAS No. 7788-97-8) (provided for in subheading 2826.19.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.46',
#     'indent': 0,
#     'description': 'Potassium fluoride hydrofluoride (CAS No. 7789-29-9) (provided for in subheading 2826.19.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.47',
#     'indent': 0,
#     'description': 'Potassium fluoroborate (CAS No. 14075-53-7) (provided for in subheading 2826.90.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.48',
#     'indent': 0,
#     'description': 'Potassium fluotitanate (Dipotassium hexafluorotitanate(2-)) (CAS No. 16919-27-0) (provided for in subheading 2826.90.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.49',
#     'indent': 0,
#     'description': 'Potassium zirconate (CAS No.16923-95-8) (provided for in subheading 2826.90.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.50',
#     'indent': 0,
#     'description': 'Titanium trichloride (CAS No. 7705-07-9) (provided for in subheading 2827.39.30)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.51',
#     'indent': 0,
#     'description': 'Cobalt chloride (dichlorocobalt hydrate (1:1)) (CAS No. 7791-13-1) (provided for in subheading 2827.39.60)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.52',
#     'indent': 0,
#     'description': 'Cesium Chloride (CAS No. 7647-17-8) (provided for in subheading 2827.39.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.53',
#     'indent': 0,
#     'description': 'Cesium iodide (CAS No. 7789-17-5) (provided for in subheading 2827.60.51)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.54',
#     'indent': 0,
#     'description': 'Sodium sulfide (CAS No. 1313-82-2) (provided for in subheading 2830.10.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.55',
#     'indent': 0,
#     'description': 'Sodium Thiosulfate Pentahydrate (Sodium sulfurothioate hydrate (2:1.5)) (CAS No.10102-17-7) (provided for in subheading 2832.30.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.56',
#     'indent': 0,
#     'description': 'Barium dinitrate (CAS No. 10022-31-8) (provided for in subheading 2834.29.51)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.57',
#     'indent': 0,
#     'description': 'Sodium hypophosphite monohydrate (CAS No. 10039-56-2) (provided for in subheading 2835.10.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.58',
#     'indent': 0,
#     'description': 'Monopotassium phosphate (CAS No. 7778-77-0) (provided for in subheading 2835.24.00)\n',
#     'superior': None,
#     'units': [],
#     'general': '1.0%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.59',
#     'indent': 0,
#     'description': 'Ammonium polyphosphate (CAS No. 68333-79-9) (provided for in subheading 2835.39.50)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.60',
#     'indent': 0,
#     'description': 'Cobalt carbonate (cobalt(2+) carbonate hydrate (1:1:1)) (CAS No. 513-79-1) (provided for in subheading 2836.99.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.61',
#     'indent': 0,
#     'description': 'Zirconium basic carbonate (zirconium(4+) dicarbonate) \n (CAS No. 57219-64-4) (provided for in subheading 2836.99.50)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.62',
#     'indent': 0,
#     'description': 'Potassium Ferricyanide (CAS No.13746-66-2) (provided for in subheading 2837.20.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.63',
#     'indent': 0,
#     'description': 'Sodium Ferrocyanide (CAS No. 13601-19-9) (provided for in subheading 2837.20.51)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.64',
#     'indent': 0,
#     'description': 'Potassium Ferrocyanide (CAS No.14459-95-1) (provided for in subheading 2837.20.51)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': ['cat'],
#    'data': {'htsno': '9902.01.65',
#     'indent': 0,
#     'description': 'Sodium oxosilanediolate hydrate (2:1:9) (Sodium metasilicate nonahydrate) (CAS No. 13517-24-3) (provided for in subheading 2839.11.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.66',
#     'indent': 0,
#     'description': 'Potassium Tetraborate (CAS No. 12045-78-2) (provided for in subheading 2840.20.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.67',
#     'indent': 0,
#     'description': 'Disodium dioxido(dioxo)tungsten (disodium wolframate) (CAS No. 13472-45-2) (provided for in subheading 2841.80.00)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.68',
#     'indent': 0,
#     'description': 'Sodium thiocyanate (CAS No. 540-72-7) (provided for in subheading 2842.90.10)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.69',
#     'indent': 0,
#     'description': 'Silver sodium zirconium hydrogenphosphate (CAS No. 265647-11-8) (provided for in subheading 2843.29.01)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.70',
#     'indent': 0,
#     'description': 'Mixtures or coprecipitates of yttrium phosphate (CAS No. 13990-54-0) and cerium phosphate (CAS No. 13454-71-2) (provided for in subheadings 2846.10.00 and 2846.90.80)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.71',
#     'indent': 0,
#     'description': 'Lanthanum(III) oxide (CAS No. 1312-81-8) (provided for in subheading 2846.90.80)',
#     'superior': None,
#     'units': [],
#     'general': '2.4%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.72',
#     'indent': 0,
#     'description': 'Lanthanum carbonate (CAS No. 54451-24-0) (provided for in subheading 2846.90.80)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.73',
#     'indent': 0,
#     'description': 'Lutetium oxide (CAS No. 12032-20-1) (provided for in subheading 2846.90.80)',
#     'superior': None,
#     'units': [],
#     'general': '2.2%',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.74',
#     'indent': 0,
#     'description': 'Lanthanum phosphate, cerium terbium-doped (CAS No. 95823-34-0) (provided for in subheading 2846.90.80)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.75',
#     'indent': 0,
#     'description': 'Yttrium oxides having a purity of at least 99.9 percent (CAS No. 1314-36-9)\n (provided for in subheading 2846.90.80)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.76',
#     'indent': 0,
#     'description': 'Ytterbium trifluoride powder (CAS No. 13760-80-0) with a median particle size of greater than 0.2 microns and less than 0.7 microns (provided for in subheading 2846.90.80)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.77',
#     'indent': 0,
#     'description': 'Titanium(2+) dihydride (Titanium hydride) (CAS No. 7704-98-5) (provided for in subheading 2850.00.07)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.78',
#     'indent': 0,
#     'description': 'Mixtures containing titanium dihydride pastes of a kind used for coating the interior of low-pressure mercury lamps (CAS No. 7704-98-5) (provided for in subheading 2850.00.07)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.79',
#     'indent': 0,
#     'description': 'Lithium tetrahydridoaluminate(1-) (Lithium aluminum hydride) (CAS No. 16853-85-3) (provided for in subheading 2850.00.50)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.80',
#     'indent': 0,
#     'description': 'Cyanamide (CAS No. 420-04-2) (provided for in subheading 2853.90.90)',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.81',
#     'indent': 0,
#     'description': 'n-Butyl chloride (1-Chlorobutane) (CAS No. 109-69-3) (provided for in subheading 2903.19.60)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.82',
#     'indent': 0,
#     'description': '1,6-Dichlorohexane (CAS No. 2163-00-0) (provided for in subheading 2903.19.60)\n',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': 'No change',
#     'other': 'No change',
#     'footnotes': [{'columns': ['stat', 'units'],
#       'marker': '1',
#       'value': 'See chapter 99 statistical note 1.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '9902.01.83',
#     'indent': 0,
#     'description': 'Allyl Bromide (3-bromo-1-propene) (CAS No. 106-95-6) (provided for in subheading 2903.39.20)',
# ...
#       'type': 'footnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': ' ',
#     'addiitionalDuties': None}},
#   ...],
#  [{'keyword': [],
#    'data': {'htsno': '2309',
#     'indent': 0,
#     'description': 'Preparations of a kind used in animal feeding:',
#     'superior': None,
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': '',
#     'additionalDuties': '',
#     'addiitionalDuties': None}},
#   {'keyword': ['cat'],
#    'data': {'htsno': '2309.10.00',
#     'indent': 1,
#     'description': 'Dog or cat food, put up for retail sale',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': '',
#     'other': '10%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.03.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.10.00.10',
#     'indent': 2,
#     'description': 'In airtight containers',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.10.00.90',
#     'indent': 2,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90',
#     'indent': 1,
#     'description': 'Other:',
#     'superior': None,
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': '',
#     'additionalDuties': '',
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10',
#     'indent': 2,
#     'description': 'Mixed feeds or mixed feed ingredients',
#     'superior': None,
#     'units': [],
#     'general': 'Free',
#     'special': '',
#     'other': '10%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.03.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10.05',
#     'indent': 3,
#     'description': 'Bird seed',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10.15',
#     'indent': 3,
#     'description': 'Other pet food, put up for retail sale',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10.20',
#     'indent': 3,
#     'description': 'Poultry feeds, prepared',
#     'superior': None,
#     'units': ['t'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': ['cat'],
#    'data': {'htsno': '2309.90.10.30',
#     'indent': 3,
#     'description': 'Dairy cattle feed, prepared',
#     'superior': None,
#     'units': ['t'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': ['cat'],
#    'data': {'htsno': '2309.90.10.32',
#     'indent': 3,
#     'description': 'Other cattle feed, prepared',
#     'superior': None,
#     'units': ['t'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10.35',
#     'indent': 3,
#     'description': 'Swine feed, prepared',
#     'superior': None,
#     'units': ['t'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10.45',
#     'indent': 3,
#     'description': 'Other livestock feed, prepared',
#     'superior': None,
#     'units': ['t'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.10.50',
#     'indent': 3,
#     'description': 'Other',
#     'superior': None,
#     'units': ['t'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '',
#     'indent': 2,
#     'description': 'Other:',
#     'superior': 'true',
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': None,
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '',
#     'indent': 3,
#     'description': 'Animal feeds containing milk or milk derivatives:',
#     'superior': 'true',
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': None,
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '',
#     'indent': 4,
#     'description': 'Containing over 10 percent by weight of milk solids:',
#     'superior': 'true',
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': None,
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.22',
#     'indent': 5,
#     'description': 'Described in general note 15 of the tariff schedule and entered pursuant to its provisions',
#     'superior': None,
#     'units': [],
#     'general': '7.5%',
#     'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.22.10',
#     'indent': 6,
#     'description': 'Milk replacer',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.22.90',
#     'indent': 6,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.24',
#     'indent': 5,
#     'description': 'Described in additional U.S. note 2 to this chapter and entered pursuant to its provisions',
#     'superior': None,
#     'units': [],
#     'general': '7.5%',
#     'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.24.10',
#     'indent': 6,
#     'description': 'Milk replacer',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.24.90',
#     'indent': 6,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.28',
#     'indent': 5,
#     'description': 'Other',
#     'superior': None,
#     'units': [],
#     'general': '80.4¢/kg + 6.4%',
#     'special': 'Free (BH,CL,JO,KR,MA,OM,PE,SG) 8¢/kg + 0.6% (P) 10.7¢/kg + 0.8% (CO,PA) See 9822.04.20 (AU) See 9823.05.01-9823.05.06 (S+) See 9915.04.20, 9915.04.24, 9915.04.28 (P+)',
#     'other': '94.6¢/kg + 7.5%',
#     'footnotes': [{'columns': ['desc'],
#       'marker': '1',
#       'value': 'See subheadings 9904.23.01-9904.23.09. ',
#       'type': 'endnote'},
#      {'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.28.10',
#     'indent': 6,
#     'description': 'Milk replacer',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.28.90',
#     'indent': 6,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '',
#     'indent': 4,
#     'description': 'Other:',
#     'superior': 'true',
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': None,
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.42',
#     'indent': 5,
#     'description': 'Described in general note 15 of the tariff schedule and entered pursuant to its provisions',
#     'superior': None,
#     'units': [],
#     'general': '7.5%',
#     'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.42.10',
#     'indent': 6,
#     'description': 'Milk replacer',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.42.90',
#     'indent': 6,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.44',
#     'indent': 5,
#     'description': 'Described in additional U.S. note 2 to this chapter and entered pursuant to its provisions',
#     'superior': None,
#     'units': [],
#     'general': '7.5%',
#     'special': 'Free (A+,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.44.10',
#     'indent': 6,
#     'description': 'Milk replacer',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.44.90',
#     'indent': 6,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.48',
#     'indent': 5,
#     'description': 'Other',
#     'superior': None,
#     'units': [],
#     'general': '80.4¢/kg + 6.4%',
#     'special': 'Free (BH,CL,JO,KR,MA,OM,PA,PE,SG) 8¢/kg + 0.6% (P) 10.7¢/kg + 0.8% (CO) See 9822.04.20 (AU) See 9823.05.01-9823.05.06 (S+) See 9915.04.20, 9915.04.24, 9915.04.28 (P+)',
#     'other': '94.6¢/kg + 7.5%',
#     'footnotes': [{'columns': ['desc'],
#       'marker': '1',
#       'value': 'See subheadings 9904.23.01-9904.23.09. ',
#       'type': 'endnote'},
#      {'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.48.10',
#     'indent': 6,
#     'description': 'Milk replacer',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.48.90',
#     'indent': 6,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': [],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '',
#     'indent': 3,
#     'description': 'Other:',
#     'superior': 'true',
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': None,
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.60.00',
#     'indent': 4,
#     'description': 'Animal feeds containing egg',
#     'superior': None,
#     'units': ['kg'],
#     'general': '1.9%',
#     'special': 'Free (A+,AU,BH,CL,CO,D,E, IL,JO,KR,MA,OM,P,PA,PE,S, SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.15. ',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '',
#     'indent': 4,
#     'description': 'Other:',
#     'superior': 'true',
#     'units': [],
#     'general': '',
#     'special': '',
#     'other': '',
#     'footnotes': None,
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.70.00',
#     'indent': 5,
#     'description': 'Preparations, with a basis of vitamin B<sub>12</sub>, for supplementing animal feed',
#     'superior': None,
#     'units': ['kg'],
#     'general': '1.4%',
#     'special': 'Free (A,AU,BH,CL,CO,D,E,IL,JO,KR,MA,OM,P,PA,PE,S,SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.03.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}},
#   {'keyword': [],
#    'data': {'htsno': '2309.90.95.00',
#     'indent': 5,
#     'description': 'Other',
#     'superior': None,
#     'units': ['kg'],
#     'general': '1.4%',
#     'special': 'Free (A+,AU,BH,CL,CO,D,E, IL,JO,KR,MA,OM,P,PA,PE,S, SG)',
#     'other': '20%',
#     'footnotes': [{'columns': ['general'],
#       'marker': '1',
#       'value': 'See 9903.88.03.',
#       'type': 'endnote'}],
#     'quotaQuantity': None,
#     'additionalDuties': None,
#     'addiitionalDuties': None}}]]
