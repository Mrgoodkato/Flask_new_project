# %%
import pandas as pd
import openpyxl as op
from openpyxl.styles import Font
import re

path = '../test_files/Magaya Upload - CWI 091223.xlsx'

# %%
def htsRead(path):
    df = pd.read_excel(path)
    try:
        tariffs = df['Tariff #']
    except:
        return 'Not a valid HTS file'

    index = 1
    error = False
    counter = 0

    read_result = {
        'Printout': [],
        'Tariffs-affected': [],
        'Final-df': pd.DataFrame(columns=df.columns.to_list())
    }

    for tariff in tariffs:
        index+=1
        regx = re.compile('(?:(?:[\d]{4}\.[\d]{2}\.(?:[\d]{2}|[\d]{4}))(?:$|,))|(?:(?:[\d]{8}|[\d]{10})(?:$|,))')
        no_space_tariff = re.sub(' ', '', str(tariff))
        checkTariff = re.sub(regx, '', str(no_space_tariff))
        if not checkTariff == '':
            error = True
            read_result['Final-df'].loc[counter] = df.loc[index-1]
            counter += 1
            read_result['Tariffs-affected'].append(index)
            read_result['Printout'].append('{})Tariff {} has an issue at row {}'.format(counter, tariff, index))           

    if not error:
        read_result['Printout'].append('No tariffs presented errors')


    return read_result

def highlightExcel(path, rows):
    wb = op.load_workbook(filename=path)

    sheet = wb.active

    for row in rows:
        cell = sheet['K{}'.format(row)]
        cell.font = Font(color="FF0000")

    wb.save('processed_file.xlsx')

# %%
result = htsRead(path)

result
# Out:
# {'Printout': ['1)Tariff ,9401.80.4035 has an issue at row 961',
#   '2)Tariff ,9401.80.4035 has an issue at row 962',
#   '3)Tariff ,9401.80.4035 has an issue at row 963',
#   '4)Tariff ,9401.80.4035 has an issue at row 964',
#   '5)Tariff ,9401.80.4035 has an issue at row 965',
#   '6)Tariff ,9401.80.4035 has an issue at row 966',
#   '7)Tariff ,9401.80.4035 has an issue at row 967',
#   '8)Tariff ,9401.80.4035 has an issue at row 968',
#   '9)Tariff ,9401.80.4035 has an issue at row 969',
#   '10)Tariff ,6307.20.0000 has an issue at row 970',
#   '11)Tariff ,6307.20.0000 has an issue at row 971',
#   '12)Tariff ,6307.20.0000 has an issue at row 972',
#   '13)Tariff ,6307.20.0000 has an issue at row 973',
#   '14)Tariff ,6307.20.0000 has an issue at row 974',
#   '15)Tariff ,6307.20.0000 has an issue at row 975'],
#  'Tariffs-affected': [961,
#   962,
#   963,
#   964,
#   965,
#   966,
#   967,
#   968,
#   969,
#   970,
#   971,
#   972,
#   973,
#   974,
#   975],
#  'Final-df':    ImporterAccount FilerCode    PartNumber
#  0        CWII00001       E37        137038  \
#  1        CWII00001       E37        360849
#  2        CWII00001       E37        742222
#  3        CWII00001       E37        742223
#  4        CWII00001       E37        742224
#  5        CWII00001       E37        747204
#  6        CWII00001       E37        747205
#  7        CWII00001       E37        747206
#  8        CWII00001       E37        747478
#  9        CWII00001       E37        747479
#  10       CWII00001       E37        747480
#  11       CWII00001       E37        747575
#  12       CWII00001       E37        747608
#  13       CWII00001       E37  747609 RBYL
#  14       CWII00001       E37        320205
#
#                              Description Country UnitPrice IsDutyExempt
#  0             137038 * ZUP ZOOM 2P TUBE     NaN       NaN            0  \
#  1     360849 * YOU GOTTHIS BOARD 2.0 BL     NaN       NaN            0
#  2         742222 * NAUTICA 1 TO 2P TUBE     NaN       NaN            0
#  3         742223 * NAUTICA 2P DECK TUBE     NaN       NaN            0
#  4         742224 * NAUTICA 3P DECK TUBE     NaN       NaN            0
#  5         747204 * NAUT 2P CHARIOT TUBE     NaN       NaN            0
#  6         747205 * NAUT 3P CHARIOT TUBE     NaN       NaN            0
#  7         747206 * NAUT 4P CHARIOT TUBE     NaN       NaN            0
#  8          747478 * NAUT 4FT11 WAKESURF     NaN       NaN            0
#  9           747479 * NAUT 5FT4 WAKESURF     NaN       NaN            0
#  10           747480 * NAUT DOMORE BOARD     NaN       NaN            0
#  11         747575 * ZUP SURF ZIMICHURRI     NaN       NaN            0
#  12        747608 * GTR BELLATOR 1P TUBE     NaN       NaN            0
#  13  747609 RBYL  * GLADIATOR BOOST BALL     NaN       NaN            0
#  14        320205 * GTI 4-TEC (RENTAL ST     NaN       NaN            0
#
#     IsDutyReduced IsMPFExempt IsOtherFeesExempt  ... AGENCY PROGRAM CODE
#  0            NaN           0                 0  ...                 NaN  \
#  1            NaN           0                 0  ...                 NaN
#  2            NaN           0                 0  ...                 NaN
#  3            NaN           0                 0  ...                 NaN
#  4            NaN           0                 0  ...                 NaN
#  5            NaN           0                 0  ...                 NaN
#  6            NaN           0                 0  ...                 NaN
#  7            NaN           0                 0  ...                 NaN
#  8            NaN           0                 0  ...                 NaN
#  9            NaN           0                 0  ...                 NaN
#  10           NaN           0                 0  ...                 NaN
#  11           NaN           0                 0  ...                 NaN
#  12           NaN           0                 0  ...                 NaN
#  13           NaN           0                 0  ...                 NaN
#  14           NaN           0                 0  ...                 NaN
#
#     AGENCY PROCESSING CODE PRODUCT CODE  QUALIFIER PRODUCT CODE NUMBER
#  0                     NaN                     NaN                 NaN  \
#  1                     NaN                     NaN                 NaN
#  2                     NaN                     NaN                 NaN
#  3                     NaN                     NaN                 NaN
#  4                     NaN                     NaN                 NaN
#  5                     NaN                     NaN                 NaN
#  6                     NaN                     NaN                 NaN
#  7                     NaN                     NaN                 NaN
#  8                     NaN                     NaN                 NaN
#  9                     NaN                     NaN                 NaN
#  10                    NaN                     NaN                 NaN
#  11                    NaN                     NaN                 NaN
#  12                    NaN                     NaN                 NaN
#  13                    NaN                     NaN                 NaN
#  14                    NaN                     NaN                 NaN
#
#     PACKAGING QUALIFIER 1 UNIT OF MEASURE 1 PACKAGING QUALIFIER 2
#  0                    NaN               NaN                   NaN  \
#  1                    NaN               NaN                   NaN
#  2                    NaN               NaN                   NaN
#  3                    NaN               NaN                   NaN
#  4                    NaN               NaN                   NaN
#  5                    NaN               NaN                   NaN
#  6                    NaN               NaN                   NaN
#  7                    NaN               NaN                   NaN
#  8                    NaN               NaN                   NaN
#  9                    NaN               NaN                   NaN
#  10                   NaN               NaN                   NaN
#  11                   NaN               NaN                   NaN
#  12                   NaN               NaN                   NaN
#  13                   NaN               NaN                   NaN
#  14                   NaN               NaN                   NaN
#
#     UNIT OF MEASURE 2 PGA Disclaim Code Manufacturer
#  0                NaN               NaN          NaN
#  1                NaN               NaN          NaN
#  2                NaN               NaN          NaN
#  3                NaN               NaN          NaN
#  4                NaN               NaN          NaN
#  5                NaN               NaN          NaN
#  6                NaN               NaN          NaN
#  7                NaN               NaN          NaN
#  8                NaN               NaN          NaN
#  9                NaN               NaN          NaN
#  10               NaN               NaN          NaN
#  11               NaN               NaN          NaN
#  12               NaN               NaN          NaN
#  13               NaN               NaN          NaN
#  14               NaN               NaN          NaN
#
#  [15 rows x 33 columns]}

# %%
highlight = highlightExcel(path, [961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975])
